# %% [markdown]
# # Python Matplotlib

# %% [markdown]
# ##### grid() function
# - Use the grid() function to add grid lines to the plot

# %% [markdown]
# ##### Importing Libararies

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid()
plt.show()

# %% [markdown]
# - Use the axis parameter in the grid() function to specify which grid lines to display.
# - Legal values are: 'x', 'y', and 'both'. Default value is both

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(axis = 'x')

# %% [markdown]
# ##### Exercise
# - Plot the previous graph with y grid

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(axis = 'y')

# %% [markdown]
# ##### Set Line Properties for the Grid
# - Line properties of the grid, like this: grid(color = 'color', linestyle = 'linestyle', linewidth = number)

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# ##### Super Title
# - You can add a title to subplots of the entire figure with the suptitle() function

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")
plt.suptitle("MY SHOP")
# Out:
# Text(0.5, 0.98, 'MY SHOP')

# %% [markdown]
# ##### Creating Scatter Plots
# - With Pyplot, you can use the scatter() function to draw a scatter plot.
# - The scatter() function plots one dot for each observation.
# - It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis.

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ##### Compare Plots
# - To find the relationship between two plots we can draw them on a single figure

# %%
#company one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
#company two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)
plt.xlabel('Age of Car')
plt.ylabel('Speed of Car')
plt.show()

# %% [markdown]
# ##### Colors
# - You can set your own color for each scatter plot with the color or the c argument

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'pink')
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')
plt.show()

# %% [markdown]
# ##### Color Each Dot
# - You can even set a specific color for each dot by using an array of colors as value for the c argument
# - Use the color argument for this, only the c argument

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# ##### Color Map
# - A colormap is like a list of colors, where each color has a value that ranges from 0 to 100
# - This colormap is called 'viridis' and as you can see it ranges from 0, which is a purple color, and up to 100, which is a yellow color

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 
70, 80, 90, 100])
plt.scatter(x, y, c=colors, cmap='viridis')
plt.show()

# %% [markdown]
# ##### plt.colorbar()
# - Including the colormap in the drawing by including the plt.colorbar() statement

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# ##### Size
# - s argument changes the size of the dot
# - Make sure the array for sizes has the same length as the arrays for the x- and y-axis

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x, y, s=sizes, c='#88c999')
plt.show()

# %% [markdown]
# ##### Alpha
# - The transparency of the dots can be adjusted with the alpha argument.

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x, y, s=sizes, c='#88c999', alpha=0.9)
plt.show()

# %% [markdown]
# ##### Combine Color Size and Alpha
# - Combine a colormap with different sizes on the dots. This is best visualized if the dots are transparent

# %% [markdown]
# ##### Exercise: Create random arrays with 100 values for x-points, y-points, colors and sizes. Set alpha to 0.5 and cmap to 'nipy_spectral‘

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()
plt.show()

# %% [markdown]
# ##### Creating Bars
# - With Pyplot, using the bar() function to draw bar graphs

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ##### Horizontal Bars
# - For the bars to be displayed horizontally instead of vertically, use the barh() function

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.barh(x, y)
plt.show()

# %% [markdown]
# ##### Bar Color
# - The bar() and barh() takes the keyword argument color to set the color of the bars

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x, y, color = "red")
plt.show()

# %% [markdown]
# ##### Color Hex
# - Using Hexadecimal color value

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x, y, color = "#4BA050")
plt.show()

# %% [markdown]
# ##### Bar Width
# - The bar() takes the keyword argument width to set the width of the bars

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x, y, width = 0.1)
plt.show()

# %% [markdown]
# ##### Bar height
# - The barh() takes the keyword argument height to set the height of the bars

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# ##### Display the value of each bar in a bar chart
# - Using matplotlib.pyplot.text() function

# %%
x = ["A", "B", "C", "D"]
y = [1, 2, 3, 4]
plt.barh(x, y)  
for index, value in enumerate(y):
    plt.text(value, index, str(value))
plt.show()

# %% [markdown]
# ##### Exercise : Shift the previous example to vertical bar graph

# %%
x = ["A", "B", "C", "D"]
y = [1, 2, 3, 4]
plt.bar(x, y)  
for index, value in enumerate(y):
    plt.text(index, value,
             str(value))  
plt.show()

# %% [markdown]
# ##### Multiple Bar Charts
# - When comparing several quantities we might want a bar chart where we have bars of one color for one quantity value

# %%
data = [[30, 25, 50, 20],
[40, 23, 51, 17],
[35, 22, 45, 19]]
X = np.arange(4)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, data[0], color = 'b', width = 0.25)
ax.bar(X + 0.25, data[1], color = 'g', width = 0.25)
ax.bar(X + 0.50, data[2], color = 'r', width = 0.25)
ax.legend(labels=['CS', 'IT','E&CT'])

# %% [markdown]
# ##### Stacked Bar Charts
# - The stacked bar chart stacks bars that represent different groups on top of each other.
# - The optional bottom parameter of the pyplot.bar() function allows you to specify a starting value for a bars

# %%
N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
ind = np.arange(N) # the x locations for the groups
width = 0.35
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(ind, menMeans, width, color='r')
ax.bar(ind, womenMeans, width, bottom=menMeans, color='b')
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend(labels=['Men', 'Women'])
plt.show()

# %% [markdown]
# ##### Exercise: Create a data frame of education and salaries education = ["Bachelor's", "Less than Bachelor's","Master's","PhD","Professional"] salary = [110000,105000,126000,144200,95967].Plot them in bar plot in ascending order and save the figure.

# %%
import pandas as pd
education = ["Bachelor's", "Less than Bachelor's","Master's","PhD","Professional"]
# mean annual salary in US dollars
salary = [110000,105000,126000,144200,95967]
# create Pandas dataframe from two lists
df = pd.DataFrame({"Education":education,"Salary":salary})
df_sorted= df.sort_values('Salary')
plt.figure(figsize=(10,6))
# bar plot with matplotlib
plt.bar('Education', 'Salary',data=df_sorted)
plt.xlabel("Education", size=15)
plt.ylabel("Salary in US Dollars", size=15)
plt.title("Bar plot in Ascending Order with Matplotlib", size=18)
plt.savefig("bar_plot_matplotlib_ascending_order_Python.png")

# %% [markdown]
# #### Create Histogram
# - In Matplotlib, we use the hist() function to create histograms

# %%
x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show()

# %% [markdown]
# ##### Example: Create Histogram using bin

# %%
fig,ax = plt.subplots(1,1)
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
ax.hist(a, bins = [0,25,50,75,100])
ax.set_title("histogram of result")
ax.set_xlabel('marks')
ax.set_ylabel('no. of students')
plt.show()

# %% [markdown]
# ##### Example: Create Histogram of depth values(one column) from diamonds dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv')
df.head()
x=df['depth'] 
plt.hist(x)
# Out:
# (array([3.0000e+00, 0.0000e+00, 1.1000e+01, 2.6800e+02, 1.2078e+04,
#         4.0363e+04, 1.1320e+03, 7.8000e+01, 4.0000e+00, 3.0000e+00]),
#  array([43. , 46.6, 50.2, 53.8, 57.4, 61. , 64.6, 68.2, 71.8, 75.4, 79. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ##### Example: Create Histogram of depth values(one column) from diamonds dataset in 5 bins

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv')
df.head()
x=df['depth']
plt.hist(x, bins=5)
# Out:
# (array([3.0000e+00, 2.7900e+02, 5.2441e+04, 1.2100e+03, 7.0000e+00]),
#  array([43. , 50.2, 57.4, 64.6, 71.8, 79. ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ##### Example: Create Histogram of depth values(one column) for which the cut is ideal

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ##### Example: Create Histogram for the cut value where it is ideal

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv')
df.head()
x=df.loc[df.cut=='Ideal']
x1=x['depth']
plt.hist(x1)
#Or
#x1 = df.loc[df.cut=='Ideal', 'depth']

# %% [markdown]
# ##### Example: Compare the Histogram of depth values for which cut is ideal, fair and good

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv')
df.head()
x1 = df.loc[df.cut=='Ideal', 'depth']
x2 = df.loc[df.cut=='Fair', 'depth']
x3 = df.loc[df.cut=='Good', 'depth']
plt.hist(x1, color='g', label='Ideal')
plt.hist(x2, color='b', label='Fair')
plt.hist(x3, color='r', label='Good')
plt.title("Frequency Histogram of Diamond Depths")
plt.ylabel('Frequency')
plt.xlabel('Multi Histogram')
plt.xlim(50,75)
plt.legend()

# %% [markdown]
# ##### Example: Compare the Histogram of color E,I and J with respect to their prices. Set the transparency to 0.5 and bins to 100!

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv')
df.head()
x1 = df.loc[df.color=='E', 'price']
x2 = df.loc[df.color=='I', 'price']
x3 = df.loc[df.color=='J', 'price']
kwargs = dict(alpha=0.5, bins=100)
plt.hist(x1,**kwargs,color='g', label='E')
plt.hist(x2,**kwargs,  color='b', label='I')
plt.hist(x3, **kwargs, color='r', label='J')
plt.title("Frequency Histogram of Diamond prices")
plt.xlabel('Multi Histogram')
plt.ylabel('Frequency')
plt.xlim(0,17500)
plt.legend()

# %% [markdown]
# ##### Exercise : Subplot the histograms of all the cuts of diamonds.

# %%
# Import Data
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv')
fig, axes = plt.subplots(1, 5, figsize=(10,2.5), dpi=100)
colors = ['red', 'blue', 'green', 'pink', 'olive']
for i, (ax, cut) in enumerate(zip(axes.flatten(), df.cut.unique())):
    x = df.loc[df.cut==cut, 'depth']
    ax.hist(x, alpha=0.5, bins=100, label=str(cut), color=colors[i])
    ax.set_title(cut)
plt.suptitle('Probability Histogram of Diamond Depths', y=1.05, size=16)
plt.tight_layout()

# %%
# Import data
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv')
x1 = df.loc[df.cut=='Ideal', ['depth']]
x2 = df.loc[df.cut=='Fair', ['depth']]
x3 = df.loc[df.cut=='Good', ['depth']]
fig, axes = plt.subplots(1, 3, figsize=(10, 3), sharey=True, dpi=100)
sns.distplot(x1 , color="dodgerblue", ax=axes[0], axlabel='Ideal')
sns.distplot(x2 , color="deeppink", ax=axes[1], axlabel='Fair')
sns.distplot(x3 , color="gold", ax=axes[2], axlabel='Good')
plt.xlim(50,75)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ##### Exercise: Load the iris dataset and plot the histogram and density plot for the sepal length for setosa, virginica, versicolor.

# %%
import seaborn as sns
df = sns.load_dataset('iris')
plt.subplots(figsize=(7,6), dpi=100)
sns.distplot( df.loc[df.species=='setosa', "sepal_length"] , color="dodgerblue", label="Setosa")
sns.distplot( df.loc[df.species=='virginica', "sepal_length"] , color="orange", label="virginica")
sns.distplot( df.loc[df.species=='versicolor', "sepal_length"] , color="deeppink", label="versicolor")
plt.title('Iris Histogram')
plt.legend()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# #### Pie chart
# - Creating Pie Charts
# - With Pyplot, using the pie() function to draw pie charts
# - Pie chart draws one piece (called a wedge) for each value in the array
# - By default the plotting of the first wedge starts from the x-axis and move counterclockwise

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
plt.pie(y)
plt.show()

# %% [markdown]
# ##### Label Pie chart
# - With pie() function use the keyword label to label the wedge

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# ##### Start Angle
# - The default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter

# %% [markdown]
# ##### Example : Start the wedge at 90 degree

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# ##### Explode
# - To make one of the wedges standout use explode parameter
# - Each value represents how far from the center each wedge is displayed

# %% [markdown]
# ##### Example : Pull the "Apples" wedge 0.2 from the center of the pie

# %%
# import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# ##### Shadow
# - Add shadow to the pie chart by setting shadow parameter True

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# ##### Color
# - Setting the color of each wedge with the  color parameter

# %% [markdown]
# ##### Example : Specify the new color for each wedge

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["r", "pink", "y", "#4CAF50"]
plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# ##### Legends
# - To add a list of explanation for each wedge, use the legend() function

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ##### Legend with header
# - To add a header to the legend, add the title parameter to the legend function

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %% [markdown]
# ##### 3-Dimentional Plotting

# %% [markdown]
# ##### To enable three -dimensional axes set projection ='3d'

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')

# %% [markdown]
# ##### Plotting 3D lines and points
# - Graph with lines and point are the simplest 3 dimensional graph.
# - ax.plot3d and ax.scatter are the function to plot line and point graph respectively

# %% [markdown]
# ##### Example: 3 dimensional line graph

# %%
# importing mplot3d toolkits, numpy and matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt 
fig = plt.figure() 
# syntax for 3-D projection
ax = plt.axes(projection ='3d') 
# defining all 3 axes
z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z) 
# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot ')
plt.show()

# %% [markdown]
# ##### Example: 3 dimensional scatter graph

# %%
# importing mplot3d toolkits
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt 
fig = plt.figure() 
# syntax for 3-D projection
ax = plt.axes(projection ='3d') 
# defining axes
z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)
c=np.linspace(0, 100, 100)
ax.scatter(x, y, z,c=c,cmap ='viridis') 
# syntax for plotting
ax.set_title('3d Scatter plot ')
plt.show()
